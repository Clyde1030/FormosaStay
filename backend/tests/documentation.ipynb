# %% [markdown]
# # Three Layer Tests
#
# ## Layer 1 - Seed data (baseline, reusable)
# Used for:
# - Local dev
# - Manual testing
# - Smoke testing
#
# Characteristics
# - Small
# - Predictable
# - Version-controlled
#
# Examples:
# - 1 building
# - 3 rooms
# - 2 tenants
# - 1 active lease
# - 1 expired lease
#
# ## Layer 2 - Scenario data (business logic testing)
# 📌 This validates your rules, not your DB.
# Used for:
# - Edge cases
# - Domain rules
#
# Examples:
# - Tenant with overlapping leases (should fail)
# - Room marked unavailable
# - Lease ended but payment still pending
# - Soft-deleted tenant referenced by old lease
#
#
# ## Layer 3 - Load / fake data (optional, later)
# 📌 Do this after logic is correct.
#
# Used for:
# - Performance testing
# - Pagination behavior
# - Index validation
# Thousands of rows via Faker.
